# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt

# %%
x=random.rand(1, 1000)

# %%
counts, bins = np.histogram(x,100)
plt.stairs(counts, bins)
plt.xlabel("Random numbers 0-1")
plt.ylabel("Count")
plt.savefig("histogram1.pdf")
